# %%
import pandas as pd
import numpy as np
import tensorflow

# %% [markdown]
# # Data Cleaning

# %%
#Reading csv and datacleanup
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# Set features to be used as x values.
target = df['koi_disposition']
data = df.drop('koi_disposition', axis=1)
features = data.columns

# %%
#create train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=1)

# %%
from sklearn.preprocessing import MinMaxScaler

# Scale your data
X_scaler = MinMaxScaler().fit(X_train)

#Transformation
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr_classifier = LogisticRegression(max_iter= 100, solver='liblinear')

# %%
#Fit model
lr_classifier.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
#Score
print(f"Training Data Score: {lr_classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {lr_classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8380698073621972
# Testing Data Score: 0.8558352402745996

# %% [markdown]
# # Utilizing Grid Search to find best parameters

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'C': [100, 10, 1.0, 0.1, 0.01],
              'penalty': ['l1', 'l2']}

grid = GridSearchCV(lr_classifier, param_grid, verbose=3)

# %%
# Fit the model using the grid search estimator.
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END ..............................C=100, penalty=l1; total time=  15.2s
# [CV 2/5] END ..............................C=100, penalty=l1; total time=  52.4s
# [CV 3/5] END ..............................C=100, penalty=l1; total time=  41.8s
# [CV 4/5] END ..............................C=100, penalty=l1; total time=  21.2s
# [CV 5/5] END ..............................C=100, penalty=l1; total time=  23.7s
# [CV 1/5] END ..............................C=100, penalty=l2; total time=   0.5s
# [CV 2/5] END ..............................C=100, penalty=l2; total time=   0.5s
# [CV 3/5] END ..............................C=100, penalty=l2; total time=   0.5s
# [CV 4/5] END ..............................C=100, penalty=l2; total time=   0.5s
# [CV 5/5] END ..............................C=100, penalty=l2; total time=   0.4s
# [CV 1/5] END ...............................C=10, penalty=l1; total time=   4.5s
# [CV 2/5] END ...............................C=10, penalty=l1; total time=   3.9s
# [CV 3/5] END ...............................C=10, penalty=l1; total time=   5.1s
# [CV 4/5] END ...............................C=10, penalty=l1; total time=   7.6s
# [CV 5/5] END ...............................C=10, penalty=l1; total time=  11.2s
# [CV 1/5] END ...............................C=10, penalty=l2; total time=   0.4s
# [CV 2/5] END ...............................C=10, penalty=l2; total time=   0.3s
# [CV 3/5] END ...............................C=10, penalty=l2; total time=   0.3s
# [CV 4/5] END ...............................C=10, penalty=l2; total time=   0.4s
# [CV 5/5] END ...............................C=10, penalty=l2; total time=   0.2s
# [CV 1/5] END ..............................C=1.0, penalty=l1; total time=   0.7s
# [CV 2/5] END ..............................C=1.0, penalty=l1; total time=   0.4s
# [CV 3/5] END ..............................C=1.0, penalty=l1; total time=   0.6s
# [CV 4/5] END ..............................C=1.0, penalty=l1; total time=   0.8s
# [CV 5/5] END ..............................C=1.0, penalty=l1; total time=   0.6s
# [CV 1/5] END ..............................C=1.0, penalty=l2; total time=   0.1s
# [CV 2/5] END ..............................C=1.0, penalty=l2; total time=   0.2s
# [CV 3/5] END ..............................C=1.0, penalty=l2; total time=   0.1s
# [CV 4/5] END ..............................C=1.0, penalty=l2; total time=   0.2s
# [CV 5/5] END ..............................C=1.0, penalty=l2; total time=   0.2s
# [CV 1/5] END ..............................C=0.1, penalty=l1; total time=   0.1s
# [CV 2/5] END ..............................C=0.1, penalty=l1; total time=   0.2s
# [CV 3/5] END ..............................C=0.1, penalty=l1; total time=   0.1s
# [CV 4/5] END ..............................C=0.1, penalty=l1; total time=   0.2s
# [CV 5/5] END ..............................C=0.1, penalty=l1; total time=   0.2s
# [CV 1/5] END ..............................C=0.1, penalty=l2; total time=   0.1s
# [CV 2/5] END ..............................C=0.1, penalty=l2; total time=   0.1s
# [CV 3/5] END ..............................C=0.1, penalty=l2; total time=   0.1s
# [CV 4/5] END ..............................C=0.1, penalty=l2; total time=   0.1s
# [CV 5/5] END ..............................C=0.1, penalty=l2; total time=   0.1s
# [CV 1/5] END .............................C=0.01, penalty=l1; total time=   0.2s
# [CV 2/5] END .............................C=0.01, penalty=l1; total time=   0.1s
# [CV 3/5] END .............................C=0.01, penalty=l1; total time=   0.1s
# [CV 4/5] END .............................C=0.01, penalty=l1; total time=   0.3s
# [CV 5/5] END .............................C=0.01, penalty=l1; total time=   0.1s
# [CV 1/5] END .............................C=0.01, penalty=l2; total time=   0.1s
# [CV 2/5] END .............................C=0.01, penalty=l2; total time=   0.1s
# [CV 3/5] END .............................C=0.01, penalty=l2; total time=   0.1s
# [CV 4/5] END .............................C=0.01, penalty=l2; total time=   0.2s
# [CV 5/5] END .............................C=0.01, penalty=l2; total time=   0.1s
# GridSearchCV(estimator=LogisticRegression(solver='liblinear'),
#              param_grid={'C': [100, 10, 1.0, 0.1, 0.01],
#                          'penalty': ['l1', 'l2']},
#              verbose=3)

# %%
# List the best parameters for this datase
print(grid.best_params_)
# Out:
# {'C': 100, 'penalty': 'l1'}

# %%
# List the best score
print(grid.best_score_)
# Out:
# 0.8764040998697414

# %%
# Make predictions with the hypertuned model
predictions = grid.predict(X_test_scaled)
predictions
# Out:
# array(['CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', ...,
#        'FALSE POSITIVE', 'FALSE POSITIVE', 'CANDIDATE'], dtype=object)

# %%
# Calculate classification report
# YOUR CODE HERE
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.86      0.67      0.75       404
#      CONFIRMED       0.74      0.89      0.81       435
# FALSE POSITIVE       0.99      1.00      0.99       909
#
#       accuracy                           0.89      1748
#      macro avg       0.87      0.85      0.85      1748
#   weighted avg       0.90      0.89      0.89      1748

# %%
#Save model
import joblib
filename = 'lr_model.sav'
joblib.dump(lr_classifier, filename)
# Out:
# ['lr_model.sav']
